# %%
import pandas as pd
data = pd.read_csv("pregoes2020.csv") 
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    pk           dataPregao codNegociacao  tipoMercado  abertura  \
# 0   1  2020-01-02 00:00:00         AALR3            1     18.29
# 1   2  2020-01-02 00:00:00        AAPL34            1    120.00
# 2   3  2020-01-02 00:00:00         ABCB4            1     20.00
# 3   4  2020-01-02 00:00:00         ABEV3            1     18.86
# 4   5  2020-01-02 00:00:00         ADHM3            1      2.55
#
#    maximoIntraday  minimoIntraday  medioIntraday  fechamentoIntraday  \
# 0           19.00           18.28          18.68               19.00
# 1          121.34          120.00         120.73              121.34
# 2           20.30           19.82          20.05               20.30
# 3           19.25           18.78          19.12               19.20
# 4            2.55            2.35           2.44                2.48
#
#    melhorCompra  melhorVenda  totalNegocios  quantidadeTotal  volumeTotal  \
# 0         18.99        19.01            244           585800   1094619600
# ...

# %%
data.loc[data['codNegociacao']=="ABEV3"]
# Out:
#             pk           dataPregao codNegociacao  tipoMercado  abertura  \
# 3            4  2020-01-02 00:00:00         ABEV3            1     18.86
# 615       1040  2020-01-03 00:00:00         ABEV3            1     18.95
# 1309      2137  2020-01-06 00:00:00         ABEV3            1     18.86
# 2008      3403  2020-01-07 00:00:00         ABEV3            1     19.05
# 2668      4467  2020-01-08 00:00:00         ABEV3            1     19.09
# ...        ...                  ...           ...          ...       ...
# 118152  191321  2020-09-04 00:00:00         ABEV3            1     12.69
# 119102  192861  2020-09-08 00:00:00         ABEV3            1     12.55
# 119949  194312  2020-09-09 00:00:00         ABEV3            1     12.41
# 120748  195608  2020-09-10 00:00:00         ABEV3            1     12.32
# 121537  196873  2020-09-11 00:00:00         ABEV3            1     12.37
#
#         maximoIntraday  minimoIntraday  medioIntraday  fechamentoIntraday  \
# ...

# %%
df = data.loc[data['codNegociacao']=="ABEV3"]

# %%
df.describe()
# Out:
#                   pk  tipoMercado    abertura  maximoIntraday  minimoIntraday  \
# count     175.000000        175.0  175.000000      175.000000      175.000000
# mean    95915.348571          1.0   14.137200       14.389886       13.850629
# std     56645.405713          0.0    2.325333        2.280099        2.353223
# min         4.000000          1.0   10.730000       11.210000       10.360000
# 25%     47730.500000          1.0   12.335000       12.590000       11.995000
# 50%     94786.000000          1.0   13.600000       13.720000       13.210000
# 75%    143684.500000          1.0   14.920000       15.400000       14.680000
# max    196873.000000          1.0   19.200000       19.580000       18.980000
#
#        medioIntraday  fechamentoIntraday  melhorCompra  melhorVenda  \
# count     175.000000          175.000000    175.000000   175.000000
# mean       14.107371           14.082857     14.074229    14.096971
# ...

# %%
df["maximoIntraday"]
# Out:
# 3         19.25
# 615       19.16
# 1309      19.17
# 2008      19.23
# 2668      19.16
#           ...
# 118152    12.72
# 119102    12.55
# 119949    12.47
# 120748    12.62
# 121537    12.38
# Name: maximoIntraday, Length: 175, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.plot(df["dataPregao"],df["fechamentoIntraday"])
plt.show()
